# %%
# len function

name = "My name is Ridoy"
print(name)
len(name)
# Out:
# My name is Ridoy
# 16

# %%
# possiteve indexing 1
# [start:stop:step]
p = "i love coding"
p[0:10:1]
# Out:
# 'i love cod'

# %%
# possiteve indexing 2

p = "i love coding"
p[0:10:2]
# Out:
# 'ilv o'

# %%
# possiteve indexing 3

p = "i love coding"
p[0:10:3]
# Out:
# 'io d'

# %%
# negative indexing -1
# [start:stop:step]

p = "i love coding"
p[-1:-10:-1]
# Out:
# 'gnidoc ev'

# %%
# negative indexing -2

p = "i love coding"
p[-1:-10:-2]
# Out:
# 'gio v'

# %%
# negative indexing -3

p = "i love coding"
p[-1:-10:-3]
# Out:
# 'gd '

# %%
# all text ulta hoye jabe

p = "i love coding"
p[-1::-1]
# Out:
# 'gnidoc evol i'

# %%
# all text ulta input

d = input("Please Write something: ")
result = d[-1::-1]
print(f"you write : {result}")
# Out:
# Please Write something:  rakib molla
# you write : allom bikar

# %%
# indexing Slicing

name = "inception BD"

# index cheaking number
name.index("B")
# jeta change korbo setake 1ta variable vitore vore dibo
a = name[10:]
# abar variable take override kore dibo
a = " bd"
# inception take ekta variable vetore vore dibo
b = name[0:9]
# a or b mane new variable 2ta + kore dile ibdexing bd hoye jabe
b+a
# Out:
# 'inception bd'

# %%
# lower function
name = "inception BD"
name.lower()
# Out:
# 'inception bd'

# %%
# upper function
name = "inception BD"
name.upper()
# Out:
# 'INCEPTION BD'

# %%
# input function + upper function added
name = input("please enter your name: ").upper()
print(name)
# Out:
# please enter your name:  rakib
# RAKIB

# %%
# input function + lower function added
name = input("please enter your name: ").lower()
print(name)
# Out:
# please enter your name:  RAKIB
# rakib
