# %%
name = "i am ridoy"

# %%
 name
# Out:
# 'i am ridoy'

# %%
type(name)
# Out:
# str

# %%
name1 = 'ks sigma boys'

# %%
type(name1)
# Out:
# str

# %%
name1
# Out:
# 'ks sigma boys'

# %%
name = "200"

# %%
type(name)
# Out:
# str

# %%
fist_name = "Ridoy"

# %%
last_name = "Hossain"

# %%
fist_name+last_name
# Out:
# 'RidoyHossain'

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
name = "my name is rakib"

# %%
len(name)
# Out:
# 16

# %%
style = "Variable short cut style"

# %%
style
# Out:
# 'Variable short cut style'

# %%
a = 10
b = 20
c = 30

# %%
c
# Out:
# 30

# %%
a, b, c = 10, 20, 30

# %%
c
# Out:
# 30

# %%
a = 50
b = 50
c = 50
s = 50

# %%
a = b = c = s = 50

# %%
s
# Out:
# 50

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
c = str(a)

# %%
type(a)
# Out:
# str

# %%
num = 10.01

# %%
num
# Out:
# 10.01

# %%
type(num)
# Out:
# float

# %%
num = str(num)

# %%
num
# Out:
# '10.01'

# %%
type(num)
# Out:
# str

# %%
num1 = 90

# %%
num1 = float(num1)

# %%
num1
# Out:
# 90.0

# %%
type(num1)
# Out:
# float

# %% [markdown]
# int(Variable name) float(Variable name) str(Variable name)
